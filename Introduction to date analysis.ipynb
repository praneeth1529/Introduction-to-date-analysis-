# %%
import random

# %%
a1=[]
a2=[]
a3=[]
a4=[]
a5=[]

# %%
import random
for _ in range(1000):
    a1.append(random.randint(0,100))
    a2.append(random.randint(50,70))
    a3.append(random.randint(10,20))
    a4.append(random.randint(5,10))
    a5.append(random.randint(20,80))

# %%
df={
     'grade':a1,
     'weight':a2,
     'friends':a3,
     'cousins':a4,
     'projects':a5
  }

# %%
import pandas as pd

# %%
 df1 = pd.DataFrame(df)

# %%
df1
# Out:
#      grade  weight  friends  cousins  projects
# 0       95      62       20        7        61
# 1       49      55       16        8        32
# 2       57      64       16        8        47
# 3       91      65       10        8        65
# 4       30      66       12        8        75
# ..     ...     ...      ...      ...       ...
# 995    100      69       18        5        23
# 996     71      69       20        7        27
# 997     12      66       17        9        23
# 998     18      64       10        6        35
# 999     30      60       11        8        35
#
# [1000 rows x 5 columns]

# %%
df1.describe()
# Out:
#             garde       weight      friends      cousins    projects
# count  1000.00000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     49.18600    60.175000    14.959000     7.524000    49.44900
# std      28.58518     6.160384     3.181736     1.712997    17.50548
# min       0.00000    50.000000    10.000000     5.000000    20.00000
# 25%      25.00000    55.000000    12.000000     6.000000    35.00000
# 50%      48.00000    60.000000    15.000000     8.000000    48.00000
# 75%      74.00000    66.000000    18.000000     9.000000    64.00000
# max     100.00000    70.000000    20.000000    10.000000    80.00000

# %%
df1['grade'].count()
# Out:
# 1000

# %%
df1['grade'].count
# Out:
# <bound method Series.count of 0       95
# 1       49
# 2       57
# 3       91
# 4       30
#       ...
# 995    100
# 996     71
# 997     12
# 998     18
# 999     30
# Name: grade, Length: 1000, dtype: int64>

# %%
friend15=df1['friends']>15

# %%
 df1[friend15]
# Out:
#      grade  weight  friends  cousins  projects
# 0       95      62       20        7        61
# 1       49      55       16        8        32
# 2       57      64       16        8        47
# 7       31      51       16        9        42
# 10      40      69       20        6        69
# ..     ...     ...      ...      ...       ...
# 991     15      54       18        9        41
# 994     20      58       18        5        43
# 995    100      69       18        5        23
# 996     71      69       20        7        27
# 997     12      66       17        9        23
#
# [458 rows x 5 columns]

# %%
grade50=df1['grade']>50

# %%
df1[friend15 & grade50]
# Out:
#      grade  weight  friends  cousins  projects
# 0       95      62       20        7        61
# 2       57      64       16        8        47
# 13      51      57       16        9        80
# 30      95      61       18        5        74
# 38      52      57       20       10        35
# ..     ...     ...      ...      ...       ...
# 974     79      65       19        6        77
# 980     51      50       18        5        61
# 988     73      53       16        5        75
# 995    100      69       18        5        23
# 996     71      69       20        7        27
#
# [216 rows x 5 columns]

# %%
df1[grade50]
# Out:
#      grade  weight  friends  cousins  projects
# 0       95      62       20        7        61
# 2       57      64       16        8        47
# 3       91      65       10        8        65
# 8       51      54       11        5        36
# 9       53      50       10       10        28
# ..     ...     ...      ...      ...       ...
# 988     73      53       16        5        75
# 989     60      70       13        7        35
# 992     56      69       15        8        47
# 995    100      69       18        5        23
# 996     71      69       20        7        27
#
# [478 rows x 5 columns]

# %%
df1[friend15 & grade50 ].count()
# Out:
# grade       216
# weight      216
# friends     216
# cousins     216
# projects    216
# dtype: int64

# %%
df1[friend15 & grade50].value_counts()
# Out:
# grade  weight  friends  cousins  projects
# 51     50      18       5        61          1
# 83     70      17       6        26          1
# 80     68      17       6        63          1
#        70      16       5        35          1
# 81     51      19       9        23          1
#                                             ..
# 67     69      17       9        48          1
# 68     54      18       8        49          1
#        64      18       10       72          1
#        68      18       9        35          1
# 100    70      20       8        41          1
# Name: count, Length: 216, dtype: int64

# %%
df1[ friend15 & grade50]. value_counts()
# Out:
# grade  weight  friends  cousins  projects
# 51     50      18       5        61          1
# 83     70      17       6        26          1
# 80     68      17       6        63          1
#        70      16       5        35          1
# 81     51      19       9        23          1
#                                             ..
# 67     69      17       9        48          1
# 68     54      18       8        49          1
#        64      18       10       72          1
#        68      18       9        35          1
# 100    70      20       8        41          1
# Name: count, Length: 216, dtype: int64

# %%
df1[friend15 & grade50]['weight'].value_counts()
# Out:
# weight
# 70    18
# 68    16
# 60    15
# 61    14
# 53    13
# 64    13
# 57    12
# 69    12
# 67    11
# 54    11
# 62    10
# 59    10
# 65     9
# 51     9
# 56     8
# 52     7
# 66     7
# 63     6
# 50     6
# 55     6
# 58     3
# Name: count, dtype: int64

# %%
df1[friend15 & grade50]['friends']. value_counts()
# Out:
# friends
# 18    47
# 17    44
# 20    43
# 19    43
# 16    39
# Name: count, dtype: int64

# %%
from matplotlib import pyplot as plt

# %%
df1[friend15 & grade50].plot()
# Out:
# <Axes: >

# %%
# %matplotlib inline

# %%
df1[ friend15 & grade50].plot()
# Out:
# <Axes: >

# %%
df1[ friend15 & grade50]. plot (x='grade',y ='projec
# Out:
# <Axes: xlabel='grade'>

# %%
df1[ friend15 & grade50].plot(x='grade' ,y ='projects',kind ='pie')
# Out:
# <Axes: ylabel='projects'>

# %%
df1[ friend15 & grade50].plot(x='grade' ,y ='projects',kind ='box')
# Out:
# <Axes: >

# %%
df1[friend15 & grade50].plot(x= ['grade','cousins'],y= ['projects','weight'],kind = 'scatter', title ='sample graph')
plt.xlabel('x Axis'),
plt.ylabel('y Axis'),
plt.legend('Test Date'),
plt.show()

# %%
df1.to_csv('/testdate.csv')
